# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
sample = "/tf/01_code/mylittlecodes/SleepVST_baseline/data/kiss_respiratory/A2020-EM-01-0241_bw.npy"
data = np.load(sample)

# %%
data.shape
# Out:
# (858, 150)

# %%
fig, ax = plt.subplots(figsize=(20, 5))
ax.plot(data[0][:150])
ax.set_title("Respiratory Signal Sample")
plt.show()
